# %%
from sqlalchemy import create_engine
import pandas as pd
engine = create_engine('postgresql://postgres:172216-Oakwood!@localhost:5432/Final Project UFO ')

# %%
join_query = """
SELECT * FROM arizona_ufos

"""

df = pd.read_sql_query(join_query,con=engine)

# %%
df
# Out:
#       index     row                                            summary  \
# 0         0     117   Fleet of moving stars.  ((Starlink satellites?))
# 1         1    1741                   Star-like UFO and strange sound.
# 2         2     125       Crazy light show!   ((Starlink satellites?))
# 3         3     145  Saw a bright, star like object, very high up, ...
# 4         4     982  While letting out dog out my wife came to get ...
# ...     ...     ...                                                ...
# 1956   1956  135736                     Light traveling extremely fast
# 1957   1957  135918                                No noise, just gone
# 1958   1958  136160          Bright light moving slowly across the sky
# 1959   1959  136262  On 1/18/21 at approx 23:15 hours in Glendale, ...
# 1960   1960  136615  ((HOAX??)) I received a text from my son who h...
#
#                  city state   shape       duration  \
# 0     Litchfield Park    AZ   light         1 hour
# ...

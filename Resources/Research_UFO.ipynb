# %%
# Import our dependencies
#from sklearn.model_selection import train_test_split
#from sklearn.preprocessing import StandardScaler,OneHotEncoder
import pandas as pd
import numpy as np
#import tensorflow as tf
from pathlib import Path
import os
import warnings
warnings.filterwarnings("ignore")

# %%
#  Import and read the charity_data.csv.
ufo = pd.read_csv("/Users/katiebernstein/Downloads/nuforc_reports.csv")
#ufo.head()
#ufo_count
#ufo_columns
ufo_df = ufo
#ufo_df.dtypes

# %%
# Fiter file to State of Arizona
newufo_df = ufo_df[(ufo_df.state == "AZ")]
newufo_df
# Out:
#                                                   summary             city  \
# 60      When we were about 17-18, a friend and I had j...        Encinitas
# 117      Fleet of moving stars.  ((Starlink satellites?))  Litchfield Park
# 125          Crazy light show!   ((Starlink satellites?))           Tucson
# 134     Star looking ufo in sky starts to move then di...          Phoenix
# 145     Saw a bright, star like object, very high up, ...           Tucson
# ...                                                   ...              ...
# 136848                             Tonopah Arizona lights          Tonopah
# 136866                                      MADAR Node 74         Show Low
# 136883                             Tonopah Arizona lights          Tonopah
# 136897  It was about 2:15am to 2:30am I look up in the...       Scottsdale
# 136909                Ring Light UFO expanding in and out          Gilbert
#
#        state            date_time     shape     duration  \
# ...

# %%
#look at State value counts for binning
newufo_count = newufo_df.state.value_counts()
newufo_count
# Out:
# AZ    4625
# Name: state, dtype: int64

# %%
# Find null values
for column in newufo_df.columns:
    print(f"Column {column} has {newufo_df[column].isnull().sum()} null values")
# Out:
# Column summary has 2 null values
# Column city has 7 null values
# Column state has 0 null values
# Column date_time has 25 null values
# Column shape has 176 null values
# Column duration has 203 null values
# Column stats has 0 null values
# Column report_link has 0 null values
# Column text has 2 null values
# Column posted has 25 null values
# Column city_latitude has 619 null values
# Column city_longitude has 619 null values

# %%
# drop null rows for date_time, latitude and longitude only which are float64   NaN
#newufo_df.dropna(subset=newufo_df.select_dtypes(include=np.number).columns, how='all')
newufo_df1 = newufo_df.dropna(subset=["city_latitude","city_longitude","date_time"])

# %%
# Remove columns not needed
newufo_df1.drop(columns=["report_link"], inplace=True)
newufo_df1.head()
# Out:
#                                                summary             city state  \
# 117   Fleet of moving stars.  ((Starlink satellites?))  Litchfield Park    AZ
# 125       Crazy light show!   ((Starlink satellites?))           Tucson    AZ
# 134  Star looking ufo in sky starts to move then di...          Phoenix    AZ
# 145  Saw a bright, star like object, very high up, ...           Tucson    AZ
# 149                               Strange shaped craft          Gilbert    AZ
#
#                date_time   shape     duration  \
# 117  2020-04-17T20:00:00   light       1 hour
# 125  2020-04-15T20:30:00   light   20 minutes
# 134  2020-04-12T01:00:00   other  5-7 minutes
# 145  2020-03-29T21:00:00  circle      2 hours
# 149  2019-12-13T22:15:00   other    3 minutes
#
#                                                  stats  \
# 117  Occurred : 4/17/2020 20:00  (Entered as : 04/1...
# 125  Occurred : 4/15/2020 20:30  (Entered as : 4/15...
# ...

# %%
# find duplicate entries
print(f"Duplicate entries: {newufo_df1.duplicated().sum()}")
# Out:
# Duplicate entries: 0

# %%
# convert date to datestri
newufo_df1["date_time"]
newufo_df1["date_time"].str.split("T", expand=True)
# Out:
#                  0         1
# 117     2020-04-17  20:00:00
# 125     2020-04-15  20:30:00
# 134     2020-04-12  01:00:00
# 145     2020-03-29  21:00:00
# 149     2019-12-13  22:15:00
# ...            ...       ...
# 136848  2020-07-23  19:30:00
# 136866  2020-06-12  13:46:00
# 136883  2020-07-23  19:30:00
# 136897  2019-07-08  02:15:00
# 136909  2019-04-01  23:00:00
#
# [3988 rows x 2 columns]

# %%
newcolumnlist = ["date_str", "time_str"]
newufo_df1[newcolumnlist] = newufo_df1["date_time"].str.split("T", expand=True)
newufo_df1
# Out:
#                                                   summary             city  \
# 117      Fleet of moving stars.  ((Starlink satellites?))  Litchfield Park
# 125          Crazy light show!   ((Starlink satellites?))           Tucson
# 134     Star looking ufo in sky starts to move then di...          Phoenix
# 145     Saw a bright, star like object, very high up, ...           Tucson
# 149                                  Strange shaped craft          Gilbert
# ...                                                   ...              ...
# 136848                             Tonopah Arizona lights          Tonopah
# 136866                                      MADAR Node 74         Show Low
# 136883                             Tonopah Arizona lights          Tonopah
# 136897  It was about 2:15am to 2:30am I look up in the...       Scottsdale
# 136909                Ring Light UFO expanding in and out          Gilbert
#
#        state            date_time     shape     duration  \
# ...

# %%
newufo_df2 = newufo_df1.drop(["date_time"], axis=1)

# %%
newufo_df2
# Out:
#                                                   summary             city  \
# 117      Fleet of moving stars.  ((Starlink satellites?))  Litchfield Park
# 125          Crazy light show!   ((Starlink satellites?))           Tucson
# 134     Star looking ufo in sky starts to move then di...          Phoenix
# 145     Saw a bright, star like object, very high up, ...           Tucson
# 149                                  Strange shaped craft          Gilbert
# ...                                                   ...              ...
# 136848                             Tonopah Arizona lights          Tonopah
# 136866                                      MADAR Node 74         Show Low
# 136883                             Tonopah Arizona lights          Tonopah
# 136897  It was about 2:15am to 2:30am I look up in the...       Scottsdale
# 136909                Ring Light UFO expanding in and out          Gilbert
#
#        state     shape     duration  \
# ...

# %%
# converting to csv
newufo_df2.to_csv('/Users/katiebernstein/Documents/Data Bootcamp/Git/Group1_Final_Project/ufo_data_cleaned4.csv')
